# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import os
import glob

# %%
base_dir = 'C:\\Users\\Admin\\Documents\\git\\maize-disease-detection'
presentation_images_dir = os.path.join(base_dir, 'data', 'presentation')
os.listdir(presentation_images_dir)
# Out:
# ['common rust', 'gray leaf spot', 'nother corn leaf blight']

# %%
#This function loads images
def load_images(path):
    images = []
    images_paths = glob.glob(path+'/*.JPG')
    for image_path in images_paths:
        image = Image.open(image_path).resize((250, 250))
        images.append(image)
    return images
    
#This function displays images
def display_images(images, title):
    plt.figure(figsize=(12,6))
    for i in range(len(images)):
        plt.subplot(1, len(images), i+1)
        plt.imshow(images[i])
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
    plt.show()

# %%
gray_leaf_spot_images = load_images(os.path.join(presentation_images_dir, 'gray leaf spot'))
common_rust_images = load_images(os.path.join(presentation_images_dir, 'common rust'))
leaf_blight_images = load_images(os.path.join(presentation_images_dir, 'nother corn leaf blight'))

# %% [markdown]
# Cercospora leaf spot (Gray leaf spot) Cercospora zeae-maydis
# https://plantvillage.psu.edu/topics/corn-maize/infos
#
# Symptoms
# Small necrotic spots with chlorotic halos on leaves which expand to rectangular lesions 1-6
# cm in length and 2-4 mm wide; as the lesions mature they turn tan in color and finally gray;
# lesions have sharp, parallel edges and are opaque; disease can develop quickly causing
# complete blighting of leaves and plant death.
#
# 1. Brown Spots with yellow rings throughout the leaf during the growing period of the Cassava
# 2. Lesions that are 0.15-0.2 cm in diameter
# 3. Serious cases can lead to holes throughout the lesions on the leaf
#
# Cause
# Fungus
#
# Comments
# Disease emergence is favored in areas where a corn crop is followed by more corn with no
# rotastion; severity and incidence of disease is likely die to continuous corn culture with
# minimum tillage and the use of susceptible hybrids in in the midwestern corn belt of the
# USA; prolonged periods of foggy or cloudy weather can cause severe Cercopora epidemics.
#
# Management
# Plant corn hybrids with resistance to the disease; crop rotation and plowing debris into
# soil may reduce levels of inoculum in the soil but may not provide control in areas where
# the disease is prevalent; foliar fungicides may be economically viable for some high yeilding
# susceptible hybrids.

# %%
display_images(gray_leaf_spot_images[:2], 'Gray Leaf Spot')

# %%
display_images(gray_leaf_spot_images[2:4], 'Gray Leaf Spot')

# %% [markdown]
# Common rust Puccinia sorghi
# https://plantvillage.psu.edu/topics/corn-maize/infos
#
# Symptoms
# Oval or elongated cinnamon brown pustules on upper and lower surfaces of leaves; pustules
# rupture and release powdery red spores; pustules turn dark brown-black as they mature and
# release dark brown powdery spores; if infection is severe, pustules may appear on tassels and
# ears and leaves may begin to yellow; in partially resistant corn hybrids, symptoms appear as
# chlorotic or necrotic flecks on the leaves which release little or no spore.
#
# Cause
# Fungus
#
# Comments
# Disease is spread by wind-borne spores; some of the most popularly grown sweet corn varieties
# have little or no resistance to the disease.
#
# Management
# The most effective method of controlling the disease is to plant resistant hybrids;
# application of appropriate fungicides may provide some degree on control and reduce disease
# severity; fungicides are most effective when the amount of secondary inoculum is still low,
# generally when plants only have a few rust pustules per leaf.

# %%
display_images(common_rust_images[:2], 'Common Rust')

# %%
display_images(common_rust_images[2:4], 'Common Rust')

# %% [markdown]
# Northern Leaf Blight Exserohilum turcicum
# https://plantvillage.psu.edu/topics/corn-maize/infos
#
# Symptoms
# In the beginning we will notice elliptical gray-green lesions on leaves. As the disease
# process this lesions become pale gray to tan color. Later stage the lesions looks dirty due
# to dark gray spores particularly under lower leaf surface. The disease can be easily
# identified in the field due to its long, narrow lesions which are unrestricted by veins.
#
# Cause
# Fungus
#
# Comments
# The disease mainly spread through rain splash and wind.
#
# Management
# Follow proper tillage to reduce fungus inoculum from crop debris. Follow crop rotation with
# non host crop. Grow available resistant varieties. In severe case of disease incidence apply
# suitable fungicide.

# %%
display_images(leaf_blight_images[:2], 'Nothern Leaf Blight')

# %%
display_images(leaf_blight_images[2:4], 'Nothern Leaf Blight')
